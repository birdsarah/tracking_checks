# %%
import os
import sys
sys.path.append(os.path.abspath(os.path.join('..')))

# %%
from utils import (
    get_profile_dir_from_part,
    get_cookie_table_for_profile,
    get_local_storage_for_profile,
    DBS,
    get_db,
    list_tables_in_db,
)

# %%
vox_dir = get_profile_dir_from_part('vox')

# %% [markdown]
# # Pre Accept (after visiting vox.com)

# %%
cookie_df = get_cookie_table_for_profile(vox_dir)
cookie_df
# Out:
#    id           baseDomain originAttributes                     name  \
# 0   1              riot.im                                  __cfduid
# 1   2       discordapp.com                                  __cfduid
# 2   3        wikipedia.org                           WMF-Last-Access
# 3   4        wikipedia.org                    WMF-Last-Access-Global
# 4   5  creativecommons.org                                  __cfduid
# 5  13           google.com                                   CONSENT
# 6  14              vox.com                   _chorus_geoip_continent
# 7  15          mozilla.org                                       _ga
# 8  16          mozilla.org                                      _gid
# 9  17          mozilla.org                        _gat_UA-36116321-1
#
#                                          value                  host path  \
# 0  d1481b8bc7ad2c3c4a76a4762c68359b51533117954              .riot.im    /
# ...

# %%
local_df = get_local_storage_for_profile(vox_dir)
local_df
# Out:
#   originAttributes                        originKey  \
# 0                   moc.xoferif.stnuocca.:https:443
# 1                   moc.xoferif.stnuocca.:https:443
# 2                            moc.xov.www.:https:443
#
#                              scope                         key  \
# 0  moc.xoferif.stnuocca.:https:443                         _st
# 1  moc.xoferif.stnuocca.:https:443  __fxa_storage.uniqueUserId
# 2           moc.xov.www.:https:443              chorus-imgs-v1
#
#                                     value
# 0                                       1
# 1  "72f63ed4-09b6-4664-b6ac-5e2205726360"
# 2                          {"webp":false}

# %%
cookie_df.to_csv('cookies_1.csv', index=False)
local_df.to_csv('local_1.csv', index=False)

# %% [markdown]
# ----
#
# # Pre Accept (going direct to a story)

# %%
cookie_df = get_cookie_table_for_profile(vox_dir)
cookie_df
# Out:
#    id           baseDomain originAttributes                     name  \
# 0   1              riot.im                                  __cfduid
# 1   2       discordapp.com                                  __cfduid
# 2   3        wikipedia.org                           WMF-Last-Access
# 3   4        wikipedia.org                    WMF-Last-Access-Global
# 4   5  creativecommons.org                                  __cfduid
# 5  13           google.com                                   CONSENT
# 6  15          mozilla.org                                       _ga
# 7  16          mozilla.org                                      _gid
# 8  17          mozilla.org                        _gat_UA-36116321-1
# 9  18              vox.com                   _chorus_geoip_continent
#
#                                          value                  host path  \
# 0  d1481b8bc7ad2c3c4a76a4762c68359b51533117954              .riot.im    /
# ...

# %%
local_df = get_local_storage_for_profile(vox_dir)
local_df
# Out:
#   originAttributes                        originKey  \
# 0                   moc.xoferif.stnuocca.:https:443
# 1                   moc.xoferif.stnuocca.:https:443
# 2                            moc.xov.www.:https:443
#
#                              scope                         key  \
# 0  moc.xoferif.stnuocca.:https:443                         _st
# 1  moc.xoferif.stnuocca.:https:443  __fxa_storage.uniqueUserId
# 2           moc.xov.www.:https:443              chorus-imgs-v1
#
#                                     value
# 0                                       1
# 1  "72f63ed4-09b6-4664-b6ac-5e2205726360"
# 2                          {"webp":false}

# %% [markdown]
# ---
#
# # After Accept (vox.com)

# %%
cookie_df = get_cookie_table_for_profile(vox_dir)
cookie_df
# Out:
#     id             baseDomain originAttributes                        name  \
# 0    1                riot.im                                     __cfduid
# 1    2         discordapp.com                                     __cfduid
# 2    3          wikipedia.org                              WMF-Last-Access
# 3    4          wikipedia.org                       WMF-Last-Access-Global
# 4    5    creativecommons.org                                     __cfduid
# 5   13             google.com                                      CONSENT
# 6   15            mozilla.org                                          _ga
# 7   16            mozilla.org                                         _gid
# 8   17            mozilla.org                           _gat_UA-36116321-1
# 9   19                vox.com                      _chorus_privacy_consent
# 10  20           voxmedia.com                      _chorus_privacy_consent
# ...

# %%
local_df = get_local_storage_for_profile(vox_dir)
local_df
# Out:
#    originAttributes                            originKey  \
# 0                        moc.xoferif.stnuocca.:https:443
# 1                        moc.xoferif.stnuocca.:https:443
# 2                                 moc.xov.www.:https:443
# 3                    moc.aidemxov.2hpargonohp.:https:443
# 4                                 moc.xov.www.:https:443
# 5                                 moc.xov.www.:https:443
# 6                                 moc.xov.www.:https:443
# 7                                 moc.xov.www.:https:443
# 8                                 moc.xov.www.:https:443
# 9                                 moc.xov.www.:https:443
# 10                                moc.xov.www.:https:443
# 11                                moc.xov.www.:https:443
# 12                                moc.xov.www.:https:443
# 13                                moc.xov.www.:https:443
# 14                                moc.xov.www.:https:443
# ...

# %%
cookie_df.to_csv('cookies_2.csv')
local_df.to_csv('local_2.csv')

# %% [markdown]
# ---
#
# # After Accept (direct to a story)

# %%
cookie_df = get_cookie_table_for_profile(vox_dir)
cookie_df
# Out:
#       id             baseDomain originAttributes  \
# 0      1                riot.im
# 1      2         discordapp.com
# 2      3          wikipedia.org
# 3      4          wikipedia.org
# 4      5    creativecommons.org
# 5     13             google.com
# 6     15            mozilla.org
# 7     16            mozilla.org
# 8     17            mozilla.org
# 9     19                vox.com
# 10    20           voxmedia.com
# 11    21           voxmedia.com
# 12    22                vox.com
# 13    23           voxmedia.com
# 14    24                vox.com
# 15    33                vox.com
# 16    34           voxmedia.com
# 17    38  scorecardresearch.com
# 18    39  scorecardresearch.com
# 19    40                vox.com
# 20    48           facebook.com
# 21    50               agkn.com
# 22    51               agkn.com
# 23    57            twitter.com
# 24    58                vox.com
# 25    63                vox.com
# 26    73        doubleclick.net
# ...

# %%
local_df = get_local_storage_for_profile(vox_dir)
local_df
# Out:
#    originAttributes                            originKey  \
# 0                        moc.xoferif.stnuocca.:https:443
# 1                        moc.xoferif.stnuocca.:https:443
# 2                                 moc.xov.www.:https:443
# 3                    moc.aidemxov.2hpargonohp.:https:443
# 4                                 moc.xov.www.:https:443
# 5                                 moc.xov.www.:https:443
# 6                                 moc.xov.www.:https:443
# 7                                 moc.xov.www.:https:443
# 8                                 moc.xov.www.:https:443
# 9                                 moc.xov.www.:https:443
# 10                                moc.xov.www.:https:443
# 11                                moc.xov.www.:https:443
# 12                                moc.xov.www.:https:443
# 13                                moc.xov.www.:https:443
# 14                                moc.xov.www.:https:443
# ...

# %%
cookie_df.to_csv('cookies_3.csv')
local_df.to_csv('local_3.csv')
